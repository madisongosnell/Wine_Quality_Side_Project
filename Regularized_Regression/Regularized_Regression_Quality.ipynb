# %% [markdown]
# # Creating Regularized Regression Models for Quality

# %%
#Reading in packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sma
import statsmodels as sm
import pylab as py
import scipy.stats as stats
import scipy as sp
import statsmodels.formula.api as smf
import sklearn
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from plotnine import *
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from statsmodels.genmod.generalized_linear_model import GLM
from scipy.stats import spearmanr
import time
from sklearn.linear_model import LassoLarsIC
from sklearn.pipeline import make_pipeline

# %%
#Reading in datasets
train = pd.read_csv("/Users/madisongosnell/Desktop/MSA Coding /Individual Project/wine_train.csv")
validation = pd.read_csv("/Users/madisongosnell/Desktop/MSA Coding /Individual Project/wine_validation.csv")
test = pd.read_csv("/Users/madisongosnell/Desktop/MSA Coding /Individual Project/wine_test.csv")

# %% [markdown]
# # Applying the Regularized Regression Models to Training Data

# %% [markdown]
# ## Ridge Regression Model

# %%
#Checked GVIF in R - found some multicollinearity so we will use regularized regression
#Performed forward and stepwise selection in R - gave us the same model in both

#Defining the model for Ridge Regression
train = train[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]
               
train = train.fillna(0)

#Make categorical variables dummy coded
train_dummy = pd.get_dummies(train, columns = ['Wine Type'])
print(train_dummy)
# Out:
#         pH  fixed acidity  residual sugar   density  alcohol  chlorides  \
# 0     3.38            6.9            6.20  0.992000    12.20      0.027
# 1     3.38            8.3            2.30  0.994260    12.70      0.070
# 2     3.39            6.4           14.70  0.998275    10.50      0.047
# 3     3.39            6.9            1.90  0.995850     9.05      0.082
# 4     3.22            5.7           16.00  0.998620     8.90      0.044
# ...    ...            ...             ...       ...      ...        ...
# 4542  3.39            8.9            1.80  0.996800     9.40      0.077
# 4543  3.20            6.6            8.50  0.995760     9.40      0.036
# 4544  3.40            6.4            7.90  0.994800    10.20      0.029
# 4545  3.00            8.9           15.75  0.996000    12.10      0.035
# 4546  3.49            6.5            1.70  0.992800    10.20      0.044
#
#       sulphates  quality  citric acid  volatile acidity  free sulfur dioxide  \
# 0          0.49        7         0.37              0.20                 24.0
# 1          0.77        7         0.42              0.33                  9.0
# 2          0.60        5         0.22              0.46                 51.0
# 3          0.43        4         0.20              0.48                  9.0
# 4          0.46        6         0.20              0.22                 41.0
# ...         ...      ...          ...               ...                  ...
# 4542       0.53        6         0.48              0.22                 29.0
# 4543       0.48        6         0.37              0.23                 46.0
# 4544       0.39        5         0.32              0.22                 34.0
# 4545       0.37        6         0.33              0.24                 16.0
# 4546       0.50        7         0.31              0.18                 30.0
#
#       total sulfur dioxide  Wine Type_Red  Wine Type_White
# 0                     97.0          False             True
# 1                     20.0           True            False
# 2                    183.0          False             True
# 3                     23.0           True            False
# 4                    113.0          False             True
# ...                    ...            ...              ...
# 4542                  60.0           True            False
# 4543                 153.0          False             True
# 4544                 124.0          False             True
# 4545                 132.0          False             True
# 4546                 127.0          False             True
#
# [4547 rows x 14 columns]

# %%
#Specifying we want our y(response) to be quality
y = train_dummy['quality']
X = train_dummy.loc[:, train_dummy.columns != 'quality']

wine_ridge = Ridge(alpha = 1.0).fit(X, y)

# %%
#Fitting the ridge model
n_alphas = 200
alphas = np.logspace(0.1, 5, n_alphas)

coefs = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X, y)
    coefs.append(ridge.coef_)

# %%
#Plotting the ridge model
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("Ridge coefficients as a function of the regularization")
plt.axis("tight")
#Penalty needs to be between 10^4 and 10^5
# Out:
# (0.716143410212902,
#  175792.36139586932,
#  -1.6273328877515751,
#  0.6882936665128525)

# %% [markdown]
# ## Lasso Regression Model

# %%
#Defining the model for Lasso Regression
train = train[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]
               
train = train.fillna(0)

#Make categorical variables dummy coded
train_dummy = pd.get_dummies(train, columns = ['Wine Type'])

# %%
#Specifying we want our y(response) to be Quality
y = train_dummy['quality']
X = train_dummy.loc[:, train_dummy.columns != 'quality']

X_scaled = StandardScaler().fit_transform(X)

#Applying Lasso Regression Model
quality_lasso = Lasso(alpha = 2, max_iter = 5000).fit(X_scaled, y)

n_alphas = 100
alphas2 = np.logspace(-3, 3, n_alphas)

coefs2 = []
for a in alphas2:
   lasso = Lasso(alpha = a, max_iter = 5000)
   lasso.fit(X_scaled, y)
   coefs2.append(lasso.coef_)

#Plotting the lasso model
plt.cla()
ax2 = plt.gca()
ax2.plot(alphas2, coefs2)
ax2.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("LASSO coefficients as a function of the regularization")
plt.axis("tight")
# Out:
# (0.0005011872336272725,
#  1995.2623149688789,
#  -0.3109197632585127,
#  0.428522543376913)

# %% [markdown]
# # Applying the Regularized Regression Models to Validation Data

# %% [markdown]
# ## Ridge Regression Model

# %%
#Defining the model for Ridge Regression
validation = validation[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]

validation = validation.fillna(0)

#Make categorical variables dummy coded
validation_dummy = pd.get_dummies(validation, columns = ['Wine Type'])
print(validation_dummy)
# Out:
#        pH  fixed acidity  residual sugar  density  alcohol  chlorides  \
# 0    3.19            6.8             6.0  0.99530      9.1      0.050
# 1    3.38            6.5            16.5  1.00000      9.5      0.045
# 2    3.44            5.8             1.5  0.99115     11.0      0.031
# 3    3.34            5.5             4.6  0.99490      9.0      0.029
# 4    3.15            6.8            16.1  0.99840      9.3      0.049
# ..    ...            ...             ...      ...      ...        ...
# 645  3.26            6.3            17.2  0.99884      9.4      0.037
# 646  3.36            5.7             9.0  0.99474     10.4      0.053
# 647  3.24           10.8             2.5  0.99818     10.8      0.099
# 648  3.39            6.9             9.6  0.99780      9.6      0.057
# 649  3.20            6.6             5.5  0.99206     11.8      0.029
#
#      sulphates  quality  citric acid  volatile acidity  free sulfur dioxide  \
# 0         0.40        5         0.34              0.32                  5.0
# 1         0.46        6         0.32              0.26                 44.0
# 2         0.55        6         0.30              0.20                 21.0
# 3         0.44        5         0.27              0.14                 22.0
# 4         0.50        5         0.26              0.27                 55.0
# ..         ...      ...          ...               ...                  ...
# 645       0.57        6         0.42              0.33                 57.0
# 646       0.37        6         0.16              0.27                 32.0
# 647       0.71        5         0.33              0.45                 20.0
# 648       0.38        6         0.30              0.16                 50.0
# 649       0.47        6         0.36              0.22                 30.0
#
#      total sulfur dioxide  Wine Type_Red  Wine Type_White
# 0                   129.0          False             True
# 1                   166.0          False             True
# 2                    57.0          False             True
# 3                   104.0          False             True
# 4                   196.0          False             True
# ..                    ...            ...              ...
# 645                 170.0          False             True
# 646                 111.0          False             True
# 647                  38.0           True            False
# 648                 185.0          False             True
# 649                 105.0          False             True
#
# [650 rows x 14 columns]

# %%
#Specifying we want our y(response) to be quality
y = validation_dummy['quality']
X = validation_dummy.loc[:, validation_dummy.columns != 'quality']

wine_ridge = Ridge(alpha = 1.0).fit(X, y)

# %%
#Fitting the ridge model
n_alphas = 200
alphas = np.logspace(0.1, 5, n_alphas)

coefs = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X, y)
    coefs.append(ridge.coef_)

# %%
#Plotting the ridge model
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("Ridge coefficients as a function of the regularization")
plt.axis("tight")
#Penalty needs to be about 10^4
# Out:
# (0.716143410212902,
#  175792.36139586932,
#  -1.1834561411216358,
#  0.6033298201754259)

# %% [markdown]
# ## Lasso Regression Model

# %%
#Defining the model for Lasso Regression
validation = validation[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]
               
validation = validation.fillna(0)

#Make categorical variables dummy coded
validation_dummy = pd.get_dummies(validation, columns = ['Wine Type'])

# %%
#Specifying we want our y(response) to be Quality
y = validation_dummy['quality']
X = validation_dummy.loc[:, validation_dummy.columns != 'quality']

X_scaled = StandardScaler().fit_transform(X)

#Applying Lasso Regression Model
quality_lasso = Lasso(alpha = 2, max_iter = 5000).fit(X_scaled, y)

n_alphas = 100
alphas2 = np.logspace(-3, 3, n_alphas)

coefs2 = []
for a in alphas2:
   lasso = Lasso(alpha = a, max_iter = 5000)
   lasso.fit(X_scaled, y)
   coefs2.append(lasso.coef_)

#Plotting the lasso model
plt.cla()
ax2 = plt.gca()
ax2.plot(alphas2, coefs2)
ax2.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("LASSO coefficients as a function of the regularization")
plt.axis("tight")
# Out:
# (0.0005011872336272725,
#  1995.2623149688789,
#  -0.22145607016119034,
#  0.4299797437298939)

# %% [markdown]
# # Applying the Regularized Regression Model to Test Data

# %% [markdown]
# ## Ridge Regression Model

# %%
#Defining the model for Ridge Regression
test = test[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]

test = test.fillna(0)

#Make categorical variables dummy coded
test_dummy = pd.get_dummies(test, columns = ['Wine Type'])
print(test_dummy)
# Out:
#         pH  fixed acidity  residual sugar  density  alcohol  chlorides  \
# 0     3.23            7.3             4.6  0.99100     13.2      0.028
# 1     3.12            7.9             7.4  0.99612      9.5      0.050
# 2     3.29            8.0             2.0  0.99720      9.2      0.073
# 3     3.22            8.4             3.1  0.99536     12.0      0.194
# 4     3.30            7.7             1.9  0.99220     11.8      0.052
# ...    ...            ...             ...      ...      ...        ...
# 1295  3.13            8.3             0.9  0.99200     10.5      0.050
# 1296  3.12            7.1            14.8  0.99518     12.0      0.024
# 1297  3.28            6.2             1.7  0.99110     11.2      0.032
# 1298  3.10            7.1            13.1  0.99800      8.8      0.050
# 1299  3.19            5.6             8.0  0.99429     10.4      0.043
#
#       sulphates  quality  citric acid  volatile acidity  free sulfur dioxide  \
# 0          0.43        6         0.37              0.43                 17.0
# 1          0.37        6         0.30              0.16                 58.0
# 2          0.61        6         0.17              0.42                  6.0
# 3          0.78        6         0.29              0.31                 14.0
# 4          0.49        6         0.42              0.22                 10.0
# ...         ...      ...          ...               ...                  ...
# 1295       0.38        6         0.35              0.20                 12.0
# 1296       0.48        8         0.29              0.47                 22.0
# 1297       0.41        7         0.32              0.30                 30.0
# 1298       0.49        5         0.24              0.32                 52.0
# 1299       0.42        6         0.25              0.23                 31.0
#
#       total sulfur dioxide  Wine Type_Red  Wine Type_White
# 0                    114.0          False             True
# 1                    152.0          False             True
# 2                     18.0           True            False
# 3                     26.0           True            False
# 4                     87.0          False             True
# ...                    ...            ...              ...
# 1295                  74.0          False             True
# 1296                 142.0          False             True
# 1297                 130.0          False             True
# 1298                 204.0          False             True
# 1299                 101.0          False             True
#
# [1300 rows x 14 columns]

# %%
#Specifying we want our y(response) to be quality
y = test_dummy['quality']
X = test_dummy.loc[:, test_dummy.columns != 'quality']

wine_ridge = Ridge(alpha = 1.0).fit(X, y)

# %%
#Fitting the ridge model
n_alphas = 200
alphas = np.logspace(0.1, 5, n_alphas)

coefs = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X, y)
    coefs.append(ridge.coef_)

# %%
#Plotting the ridge model
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("Ridge coefficients as a function of the regularization")
plt.axis("tight")
#Penalty needs to be about 10^4
# Out:
# (0.716143410212902,
#  175792.36139586932,
#  -1.7375261270121847,
#  0.6263398168350278)

# %% [markdown]
# ## Lasso Regression Model

# %%
#Defining the model for Lasso Regression
test = test[['pH', 'Wine Type', 'fixed acidity', 'residual sugar',
               'density', 'alcohol', 'chlorides', 
               'sulphates', 'quality', 'citric acid', 
               'volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide']]
               
test = test.fillna(0)

#Make categorical variables dummy coded
test_dummy = pd.get_dummies(test, columns = ['Wine Type'])

# %%
#Specifying we want our y(response) to be Quality
y = test_dummy['quality']
X = test_dummy.loc[:, test_dummy.columns != 'quality']

X_scaled = StandardScaler().fit_transform(X)

#Applying Lasso Regression Model
quality_lasso = Lasso(alpha = 2, max_iter = 5000).fit(X_scaled, y)

n_alphas = 100
alphas2 = np.logspace(-3, 3, n_alphas)

coefs2 = []
for a in alphas2:
   lasso = Lasso(alpha = a, max_iter = 5000)
   lasso.fit(X_scaled, y)
   coefs2.append(lasso.coef_)

#Plotting the lasso model
plt.cla()
ax2 = plt.gca()
ax2.plot(alphas2, coefs2)
ax2.set_xscale("log")
plt.xlabel("alpha")
plt.ylabel("weights")
plt.title("LASSO coefficients as a function of the regularization")
plt.axis("tight")
# Out:
# (0.0005011872336272725,
#  1995.2623149688789,
#  -0.3209966783404839,
#  0.3956288095678248)

# %% [markdown]
# # Calculating Mean Absolute Error

# %%
#Calculating MAE for the model
y_train = train_dummy['quality']
X_train = train_dummy.loc[:, train_dummy.columns != 'quality']
X_scaled_train = StandardScaler().fit_transform(X_train)

y_test = test_dummy['quality']
X_test = test_dummy.loc[:, test_dummy.columns != 'quality']
X_scaled_test = StandardScaler().fit_transform(X_test)

ridge = Ridge(alpha=1.0)
ridge.fit(X_scaled_train, y_train)

ridge_preds = ridge.predict(X_scaled_test)
ridge_mae = mean_absolute_error(y_test, ridge_preds)

print("Ridge Regression MAE:", ridge_mae)
# Out:
# Ridge Regression MAE: 0.5600720028954843

# %%
lasso = Lasso(alpha=2)  
lasso.fit(X_scaled_train, y_train)

lasso_preds = lasso.predict(X_scaled_test)
lasso_mae = mean_absolute_error(y_test, lasso_preds)

print("Lasso Regression MAE:", lasso_mae)
# Out:
# Lasso Regression MAE: 0.6708189677048265
